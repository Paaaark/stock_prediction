# %%
import requests
import json
from os.path import exists
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
f = open("../api_key.txt", "r")
api_key = f.readline()

# %%
def grab_daily_data(company_label, api_key):
    file_path = "../data/" + company_label + ".json"
    if exists(file_path):
        f = open(file_path)
        return json.load(f)
    url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=' + company_label + "&outputsize=full&apikey=" + api_key
    r = requests.get(url)
    data = r.json()
    with open("../data/" + company_label + ".json", "w") as output_file:
        json.dump(data, output_file)
    return data

# %%
def grab_my_predictions(company_label):
    file_path = "../data/dis_pred.json"
    f = open(file_path)
    pred_json = json.load(f)
    pred = []
    for entry in pred_json:
        pred.append(pred_json[entry])
    pred = np.array(pred).astype(float)
    return pred

# %%
def get_opening_and_closing_prices(target):
    if isinstance(target, str):
        target = grab_daily_data(target, api_key)
    closing = []
    opening = []
    for day in target['Time Series (Daily)']:
        opening.append(target['Time Series (Daily)'][day]['1. open'])
        closing.append(target['Time Series (Daily)'][day]['4. close'])
    opening = np.array(opening).astype(float)
    closing = np.array(closing).astype(float)
    return opening, closing

# %%
opening, closing = get_opening_and_closing_prices("DIS")
pred = grab_my_predictions("DIS")
opening = np.flip(opening[-730:])
closing = np.flip(closing[-730:])

# %%
plt.plot(opening)
plt.plot(closing)
plt.plot(pred)
plt.legend(["opening", "closing", "pred"])

# %%
total = 100
plus = 0
minus = 0
fee = 0.005
lost = 0
for i in range(0, 730):
    if pred[i] * (1.0 - fee) > opening[i]:
        stocks = total / opening[i]
        total = closing[i] * stocks * (1.0 - fee)
        lost += closing[i] * stocks * fee
        print("On day " + str(i) + " bought " + 
              str(stocks) + " stocks at " + 
              str(opening[i]) + " and sold at " + str(closing[i]) + 
              ". Total now is " + str(total))
        if closing[i] > opening[i]:
            plus += 1
        if closing[i] < opening[i]:
            minus += 1
# Out:
# On day 4 bought 3.9215686274509802 stocks at 25.5 and sold at 24.31. Total now is 94.85666666666665
# On day 5 bought 3.962266778056251 stocks at 23.94 and sold at 23.5. Total now is 92.64770293790029
# On day 6 bought 3.9324152350551906 stocks at 23.56 and sold at 23.63. Total now is 92.45835714433238
# On day 7 bought 3.9243784866015443 stocks at 23.56 and sold at 23.88. Total now is 93.24558746874465
# On day 8 bought 3.875543951319395 stocks at 24.06 and sold at 24.31. Total now is 93.74340108929162
# On day 9 bought 3.8262612689506783 stocks at 24.5 and sold at 25.06. Total now is 95.40667686290448
# On day 10 bought 3.732655589315512 stocks at 25.56 and sold at 25.88. Total now is 96.11812101822801
# On day 11 bought 3.696850808393385 stocks at 26.0 and sold at 26.13. Total now is 96.11571806520256
# On day 12 bought 3.7501255585330693 stocks at 25.63 and sold at 26.0. Total now is 97.01574819925051
# ...

# %%
print(plus)
print(minus)
print(total)
print(lost)
# Out:
# 138
# 97
# 139.8705328336169
# 145.53516224323917
